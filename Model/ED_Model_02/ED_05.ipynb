# %%
# import cv2 

# img = cv2.imread("02_01.jpg") # Read image 

# t_lower = 200 # Lower Threshold 
# t_upper = 200 # Upper threshold 
# aperture_size = 5 # Aperture size 
# L2Gradient = True # Boolean 

# # Applying the Canny Edge filter with L2Gradient = True 
# edge = cv2.Canny(img, t_lower, t_upper, L2gradient = L2Gradient ) 

# cv2.imshow('original', img) 
# cv2.imshow('edge', edge) 
# cv2.waitKey(0) 
# cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

# %%
def apply_canny_edge_detection(image_path, t_lower=200, t_upper=200, aperture_size=5, L2Gradient=True):
    """
    Apply Canny edge detection to the input image.

    Args:
    - image_path: Path to the input image.
    - t_lower: Lower threshold for the hysteresis procedure.
    - t_upper: Upper threshold for the hysteresis procedure.
    - aperture_size: Aperture size for the Sobel operator.
    - L2Gradient: Boolean indicating whether to use L2 gradient (Euclidean distance) or L1 gradient.

    Returns:
    - edge: The result of the Canny edge detection.
    """
    # Read the image
    img = cv2.imread(image_path)
    if img is None:
        raise ValueError(f"Failed to read image '{image_path}'")

    # Convert image to grayscale
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply Canny edge detection
    edge = cv2.Canny(gray_img, t_lower, t_upper, apertureSize=aperture_size, L2gradient=L2Gradient)

    return img, edge

# %%
def display_image_with_edges(original_img, edges):
    """
    Display the original image and its edges.

    Args:
    - original_img: The original image.
    - edges: The result of the Canny edge detection.
    """
    plt.figure(figsize=(10, 5))
    plt.subplot(121), plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))
    plt.title('Original Image'), plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(edges, cmap='gray')
    plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
    plt.show()

# %%
if __name__ == "__main__":
    image_path = '02_02.jpg'
    try:
        original_img, edges = apply_canny_edge_detection(image_path)
        display_image_with_edges(original_img, edges)
    except ValueError as e:
        print(e)
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
